# %% [markdown]
# 說明文字

# %% [markdown]
# **粗體文字**

# %% [markdown]
# *斜體文字*

# %% [markdown]
# #標題1

# %% [markdown]
# ##標題1.1

# %% [markdown]
# #標題2

# %% [markdown]
# ##標題2.1

# %% [markdown]
# # test for format as code
# x=1*1*3
# y=1**2**2
# z='mean'

# %% [markdown]
# ```
# # test for format as code
# x=1*1*3
# y=1**2**2
# z='mean'
# ```

# %%
# test for format as code
x=1*1*3
y=1**2**2
z='mean'

# %% [markdown]
# [連結文字](https://)

# %% [markdown]
# >> 縮排段落

# %% [markdown]
# ![Google logo](https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_272x92dp.png)

# %% [markdown]
# <img src="https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_272x92dp.png" width="20%">

# %% [markdown]
# [link text](https://)

# %% [markdown]
# [google](https://www.google.com/)

# %%
a=1

# %% [markdown]
# > 段落縮排

# %% [markdown]
# >>段落縮排

# %% [markdown]
# >>> 段落縮排

# %% [markdown]
# 1.   清單項目
# 2.   清單項目

# %% [markdown]
# *   清單項目
# *   清單項目

# %% [markdown]
# ---

# %% [markdown]
# ⏰

# %% [markdown]
# 這是青蛙圖
# ![frog.jpg](data:image/jpeg;base64,...)
